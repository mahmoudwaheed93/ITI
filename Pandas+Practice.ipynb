# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmoudwaheed93/ITI/blob/main/Pandas%2BPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %% [markdown]
# The file "Purchase_Data.csv" contains purchase data at a Chinese supermarket for various products.  Read this csv into a dataframe called df_data and use the head() method to check that you have read in the data correctly. Make sure you import pandas.

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import pandas
import pandas as pd
import numpy as np

file_path = '/content/drive/MyDrive/Data/Purchase_Data.csv'
df_data = pd.read_csv(file_path)


print("CSV file loaded successfully! Here are the first few rows:")
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV file loaded successfully! Here are the first few rows:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# Use the dtypes attribute to view how each column is stored

# %%
#Write your code here
#View dtypes of columns

display(df_data.dtypes)
# Out:
# invoice_number    float64
# invoice_time       object
# store_id           object
# product_id          int64
# category_id         int64
# num_item          float64
# price             float64
# dtype: object

# %%
#Write you code here
result_1 = df_data.loc[:, df_data.columns[:2]]
result_1
# Out:
#       invoice_number   invoice_time
# 0       2.020000e+11  7/15/15 10:45
# 1       2.020000e+11  7/15/15 12:16
# 2       2.020000e+11  7/15/15 12:16
# 3       2.020000e+11  7/15/15 12:16
# 4       2.020000e+11  7/15/15 12:16
# ...              ...            ...
# 5377    2.020000e+11   9/5/15 23:07
# 5378    2.020000e+11   9/5/15 23:23
# 5379    2.020000e+11   9/5/15 23:24
# 5380    2.020000e+11   9/5/15 23:32
# 5381    2.020000e+11   9/5/15 23:38
#
# [5382 rows x 2 columns]

# %% [markdown]
# Slice the first two rows using .loc and store the result in a variable called result_2.

# %%
#Write you code here
# Slice the first two rows using .loc
result_2 = df_data.loc[:1, :]
display(result_2)
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
#
#    price
# 0    2.0
# 1    2.0

# %% [markdown]
# ## Slice the first four rows and the first five columns and store the result in a variable called result_3.

# %%
#Write your code here

result_3 = df_data.loc[:3, df_data.columns[:5]]
display(result_3)
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401

# %% [markdown]
# Slice rows 0,4,6 and columns invoice time and price and store the result in variable called result_4.

# %%
#Write your code here
# Slice rows 0,4,6 and columns Age and Fare
result_4 = df_data.loc[[0, 4, 6], ["invoice_time", "price"]]
display(result_4)
# Out:
#     invoice_time  price
# 0  7/15/15 10:45    2.0
# 4  7/15/15 12:16    6.0
# 6  7/15/15 15:28    2.0

# %% [markdown]
# Store the number rows in a variable called num_rows.

# %%
# Store the number rows in a variable called num_rows.
num_rows = df_data.shape[0]

# %% [markdown]
# Print out the last row of the data to dataframe. **Hint:** use the variable num_rows from the previous exercise.

# %%
#Write your code here
# Print out the last row of the dataframe
last_row = df_data.loc[num_rows - 1, :]
display(last_row)
# Out:
# invoice_number    202000000000.0
# invoice_time        9/5/15 23:38
# store_id                    G619
# product_id              23030206
# category_id               210101
# num_item                     1.0
# price                        2.0
# Name: 5381, dtype: object

# %% [markdown]
# # Part 2

# %% [markdown]
# Compute the average and max price charged.  Store the results in variables called avg_price and max_price

# %%
#Write your code here
# Compute the average and max price charged.
avg_price = df_data['price'].mean()
max_price = df_data['price'].max()

print(f"Average price: {avg_price}")
print(f"Maximum price: {max_price}")
# Out:
# Average price: 3.1920522110741363
# Maximum price: 6.01

# %% [markdown]
# Compute the average price and average number of items purchased with only a single call to the mean() method. Store these averages in avg_price and avg_num_items.

# %%
# Compute average price and average number of items purchased
avg_price, avg_num_items = df_data[["price", "num_item"]].mean()
print("Average price:", avg_price)
print("Average num_item:", avg_num_items)
# Out:
# Average price: 3.1920522110741363
# Average num_item: 1.2983091787439613

# %% [markdown]
# Create a column called "total", which is the product of the price and num_item columns.

# %%
#Write your code here
# Create a new column "total"
df_data["total"] = df_data["price"] * df_data["num_item"]
display(df_data.head())
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price  total
# 0    2.0    2.0
# 1    2.0    2.0
# 2    2.0    2.0
# 3    6.0    6.0
# 4    6.0    6.0

# %% [markdown]
# What is the avgerage price of the three most expensive purchases?

# %%
#Write your code here
# Get the 3 most expensive purchases and compute their average price
avg_top3_price = df_data["price"].nlargest(3).mean()
print("Average price of the 3 most expensive purchases:", avg_top3_price)
# Out:
# Average price of the 3 most expensive purchases: 6.003333333333333

# %% [markdown]
# How many different products are there?

# %%
#Write your code here
# Number of different products
num_products = df_data["product_id"].nunique()
print("Number of different products:", num_products)
# Out:
# Number of different products: 53

# %% [markdown]
# Find the difference between the mean and median of the column total.  Use the describe() method and then index the dataframe it returns.

# %%
#Write your code here
# Get descriptive statistics
stats = df_data["total"].describe()

# Compute the difference between mean and median
difference = stats["mean"] - stats["50%"]
print("Difference between mean and median of total:", difference)
# Out:
# Difference between mean and median of total: 0.9318078781127839

# %% [markdown]
# Use the drop() method to delete the column total from the dataframe df_data.

# %%
#Write your code here
# Drop the column 'total'
df_data = df_data.drop("total", axis=1)
display(df_data.head())
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price
# 0    2.0
# 1    2.0
# 2    2.0
# 3    6.0
# 4    6.0

# %% [markdown]
# Let's dig a little deeper into the data set and answer some basic question.

# %%
#Write your code here
# Convert 'invoice time' column to datetime
df_data["invoice_time"] = pd.to_datetime(df_data["invoice_time"])
print(df_data.dtypes)
# Out:
# /tmp/ipython-input-3114554687.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_data["invoice_time"] = pd.to_datetime(df_data["invoice_time"])
# invoice_number           float64
# invoice_time      datetime64[ns]
# store_id                  object
# product_id                 int64
# category_id                int64
# num_item                 float64
# price                    float64
# dtype: object

# %% [markdown]
# First, covert the column invoice time to a datetime column. Print out the new column types to make sure this was done correctly

# %%
#Write your code here
# Convert 'invoice time' column to datetime
df_data["invoice_time"] = pd.to_datetime(df_data["invoice_time"])

# Print out the new column types
print(df_data.dtypes)
# Out:
# invoice_number           float64
# invoice_time      datetime64[ns]
# store_id                  object
# product_id                 int64
# category_id                int64
# num_item                 float64
# price                    float64
# dtype: object

# %% [markdown]
# Next, let's create columns called "DOW" and "Month", which store the corresponding weekday and month of the invoice respectively.  Print the head of the dataframe to make sure this was done correctly.

# %%
#Write your code here
# Create columns called "DOW" and "Month", which store the corresponding weekday and month of the invoice respectively.
df_data['DOW'] = df_data['invoice_time'].dt.day_name()
df_data['Month'] = df_data['invoice_time'].dt.month_name()

# Print the head of the dataframe to make sure this was done correctly.
display(df_data.head())
# Out:
#    invoice_number        invoice_time store_id  product_id  category_id  \
# 0    2.020000e+11 2015-07-15 10:45:00     G816     7000300       210101
# 1    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 2    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 3    2.020000e+11 2015-07-15 12:16:00     G816     7070891        70401
# 4    2.020000e+11 2015-07-15 12:16:00     G816     7090363        70401
#
#    num_item  price        DOW Month
# 0       1.0    2.0  Wednesday  July
# 1       1.0    2.0  Wednesday  July
# 2       1.0    2.0  Wednesday  July
# 3       1.0    6.0  Wednesday  July
# 4       1.0    6.0  Wednesday  July

# %% [markdown]
# Create a variable called num_purchases_wed, which stores the number of purchases made on Wednesday?  You should use value_counts and then index the series it return.

# %%
#Write your code here
# Create a variable called num_purchases_wed, which stores the number of purchases made on Wednesday?
dow_counts = df_data['DOW'].value_counts()
num_purchases_wed = dow_counts['Wednesday']

print(f"Number of purchases made on Wednesday: {num_purchases_wed}")
# Out:
# Number of purchases made on Wednesday: 959

# %% [markdown]
# # Part 3

# %% [markdown]
# In this set of practice exercises, we will be working with a demographic data regarding the passengers aboard the Titanic.  Read in the data frame and use the head() method to check that it was read in correctly.

# %%
#Write your code here

# Read in the data frame
# Please update the file path if necessary
df_titanic = pd.read_csv('/content/drive/MyDrive/Data/titanic_Data.csv')

# Use the head() method to check that it was read in correctly.
display(df_titanic.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3834093676.py in <cell line: 0>()
#       3 # Read in the data frame
#       4 # Please update the file path if necessary
# ----> 5 df_titanic = pd.read_csv('/content/drive/MyDrive/Data/titanic_Data.csv')
#       6
#       7 # Use the head() method to check that it was read in correctly.
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Data/titanic_Data.csv'

# %% [markdown]
# Use the rename method to change the column "Name" to "Passenger_Name" and the column "Ticket" to "Ticket_Num".

# %%
#Write your code here

# Use the rename method to change the column "Name" to "Passenger_Name" and the column "Ticket" to "Ticket_Num".
df_titanic = df_titanic.rename(columns={"Name": "Passenger_Name", "Ticket": "Ticket_Num"})

# Display the head to verify the changes
display(df_titanic.head())
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price
# 0    2.0
# 1    2.0
# 2    2.0
# 3    6.0
# 4    6.0

# %% [markdown]
# Change the index of the df_titanic to the column PasengerID.

# %%
#Write your code here

# Change the index of the df_titanic to the column PasengerID.
# Make sure you have loaded the correct Titanic dataset (titanic.csv) into df_titanic first.
df_titanic = df_titanic.set_index('PassengerId')

# Display the head to verify the changes
display(df_titanic.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4148820798.py in <cell line: 0>()
#       3 # Change the index of the df_titanic to the column PasengerID.
#       4 # Make sure you have loaded the correct Titanic dataset (titanic.csv) into df_titanic first.
# ----> 5 df_titanic = df_titanic.set_index('PassengerId')
#       6
#       7 # Display the head to verify the changes
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['PassengerId'] are in the columns"

# %% [markdown]
# Select the name of passenger 896

# %%
#Write your code here
# Select the name of passenger 896
passenger_name_896 = df_titanic.loc[896, 'Passenger_Name']

print(f"The name of passenger 896 is: {passenger_name_896}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Passenger_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2020037340.py in <cell line: 0>()
#       1 #Write your code here
#       2 # Select the name of passenger 896
# ----> 3 passenger_name_896 = df_titanic.loc[896, 'Passenger_Name']
#       4
#       5 print(f"The name of passenger 896 is: {passenger_name_896}")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4212             return series._values[index]
#    4213
# -> 4214         series = self._get_item_cache(col)
#    4215         engine = self.index._engine
#    4216
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _get_item_cache(self, item)
#    4636             #  pending resolution of GH#33047
#    4637
# -> 4638             loc = self.columns.get_loc(item)
#    4639             res = self._ixs(loc, axis=1)
#    4640
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Passenger_Name'

# %% [markdown]
# Change the index back to row numbers but making sure that we don't lose the PassengerId column.

# %%
#Write your code here

# Change the index back to row numbers but making sure that we don't lose the PassengerId column.
df_titanic = df_titanic.reset_index()

# Display the head to verify the changes
display(df_titanic.head())
# Out:
#    level_0  index  invoice_number   invoice_time store_id  product_id  \
# 0        0      0    2.020000e+11  7/15/15 10:45     G816     7000300
# 1        1      1    2.020000e+11  7/15/15 12:16     G816     7070884
# 2        2      2    2.020000e+11  7/15/15 12:16     G816     7070884
# 3        3      3    2.020000e+11  7/15/15 12:16     G816     7070891
# 4        4      4    2.020000e+11  7/15/15 12:16     G816     7090363
#
#    category_id  num_item  price
# 0       210101       1.0    2.0
# 1        70203       1.0    2.0
# 2        70203       1.0    2.0
# 3        70401       1.0    6.0
# 4        70401       1.0    6.0

# %% [markdown]
# How many missing entries are there in the Age column? Use the isnull() method and recall than Booleans are exactly like 1s (True) and 0s (False).

# %%
#Write you code here

# Count the number of missing entries in the Age column
missing_age_count = df_titanic['Age'].isnull().sum()

print(f"Number of missing entries in the Age column: {missing_age_count}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1867195791.py in <cell line: 0>()
#       2
#       3 # Count the number of missing entries in the Age column
# ----> 4 missing_age_count = df_titanic['Age'].isnull().sum()
#       5
#       6 print(f"Number of missing entries in the Age column: {missing_age_count}")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Age'

# %% [markdown]
# Compute the avg age of passengers ignoring the missing data.

# %%
#Write your code here
# Compute the average age ignoring missing data
avg_age = df_titanic["Age"].mean()
print("Average age of passengers:", avg_age)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2366648447.py in <cell line: 0>()
#       1 #Write your code here
#       2 # Compute the average age ignoring missing data
# ----> 3 avg_age = df_titanic["Age"].mean()
#       4 print("Average age of passengers:", avg_age)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Age'

# %% [markdown]
# Using the fillna() method replace the missing values in the Age column with the mean.

# %%
#Write your code here

# Compute the mean of the Age column, ignoring missing values
mean_age = df_titanic['Age'].mean()

# Fill missing values in the Age column with the mean
df_titanic['Age'] = df_titanic['Age'].fillna(mean_age)

# Display the head to verify the changes (optional, but good practice)
display(df_titanic.head())

# You can also check if there are any remaining missing values in the Age column
print(f"\nNumber of remaining missing values in Age column: {df_titanic['Age'].isnull().sum()}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1975627718.py in <cell line: 0>()
#       2
#       3 # Compute the mean of the Age column, ignoring missing values
# ----> 4 mean_age = df_titanic['Age'].mean()
#       5
#       6 # Fill missing values in the Age column with the mean
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Age'

# %% [markdown]
# What is the average age of the 5 oldest passengers? The reset_index method will be helpful here.

# %%
#Write your code here

# Find the average age of the 5 oldest passengers
# Sort by age in descending order, select the top 5, and calculate the mean of the Age column
average_age_top_5_oldest = df_titanic.nlargest(5, 'Age')['Age'].mean()

print(f"The average age of the 5 oldest passengers is: {average_age_top_5_oldest}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-330905045.py in <cell line: 0>()
#       3 # Find the average age of the 5 oldest passengers
#       4 # Sort by age in descending order, select the top 5, and calculate the mean of the Age column
# ----> 5 average_age_top_5_oldest = df_titanic.nlargest(5, 'Age')['Age'].mean()
#       6
#       7 print(f"The average age of the 5 oldest passengers is: {average_age_top_5_oldest}")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in nlargest(self, n, columns, keep)
#    7642         Brunei      434000    12128      BN
#    7643         """
# -> 7644         return selectn.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    7645
#    7646     def nsmallest(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/methods/selectn.py in nlargest(self)
#      55     @final
#      56     def nlargest(self):
# ---> 57         return self.compute("nlargest")
#      58
#      59     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/methods/selectn.py in compute(self, method)
#     197
#     198         for column in columns:
# --> 199             dtype = frame[column].dtype
#     200             if not self.is_valid_dtype_n_method(dtype):
#     201                 raise TypeError(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Age'

# %%
# Find the average price of the three most expensive purchases
avg_price_top_3 = df_data.nlargest(3, 'price')['price'].mean()
print(f"The average price of the three most expensive purchases is: {avg_price_top_3}")
# Out:
# The average price of the three most expensive purchases is: 6.003333333333333

# %%
# Change the index back to row numbers but making sure that we don't lose the PassengerId column.
df_titanic = df_titanic.reset_index()

# Display the head to verify the changes
display(df_titanic.head())
# Out:
#    index  invoice_number   invoice_time store_id  product_id  category_id  \
# 0      0    2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1      1    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2      2    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3      3    2.020000e+11  7/15/15 12:16     G816     7070891        70401
# 4      4    2.020000e+11  7/15/15 12:16     G816     7090363        70401
#
#    num_item  price
# 0       1.0    2.0
# 1       1.0    2.0
# 2       1.0    2.0
# 3       1.0    6.0
# 4       1.0    6.0
